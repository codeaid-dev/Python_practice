# %%
#小数点数を演算するときの気になる現象
num = 0
num += 0.1
print(num) #0.1
num += 0.1
print(num) #0.2
num += 0.1
print(num) #0.30000000000000004
num += 0.1
print(num) #0.4
num += 0.1
print(num) #0.5
num += 0.1
print(num) #0.6
num += 0.1
print(num) #0.7
num += 0.1
print(num) #0.7999999999999999
num += 0.1
print(num) #0.8999999999999999
num += 0.1
print(num) #0.9999999999999999

# %%
#書式指定文字列
data1 = 123456
data2 = 3.14
data3 ='hello'
print(f'data1 = {data1:4}')
print(f'data1 = {data1:10}')
print(f'data1 = {data1:,}')
print(f'data1 = {data1:<12}')
print(f'data1 = {data1:0<12}')
print(f'data1 = {data1:>12}')
print(f'data1 = {data1:^12}')
print(f'data2 = {int(data2)}')
print(f'data2 = {data2:10f}')
print(f'data2 = {data2:.1f}')
print(f'data2 = {data2:10.3f}')
print(f'data3 = {data3:>10}')
print(f'data3 = {data3:*>10}')

# %%
#Exercise1
print("It's Python. "+'The command "py.exe" is just for Windows.')
print('It\'s Python. The command "py.exe" is just for Windows.')

# %%
#Exercise2
a=98
b=25
print('a+b=', a+b)
print('a-b=', a-b)
print('a*b=', a*b)
print('a/b=', a/b)
print('aの2乗', a**2)

# %%
#Exercise3
a = 54
b = 3.14
c = 'Osaka'
d = True
print(f'aは{type(a)}、bは{type(b)}、cは{type(c)}、dは{type(d)}')

# %%
#Exercise4
prefs = '世田谷杉並練馬品川足立西東京'
kanas = 'あいうえおかきくけこさしすせそ'
kind = 310
ch = kanas[5] #chにkanasの'か'を代入
num = 1234
print(f'{prefs[7:9]} {kind} {ch} {num}')

# %%
#Exercise5
var1 = 'アンケート'
var2 = 'Python'
var3 = 'Java'
var4 = 20
var5 = 13
print(f'{var4}人に{var1}した結果{var2}と{var3}の\
どちらが好きかの質問で、{int(var5/var4*100)}%がPythonだった')

# %%
#Exercise6
n = int(input('ルーレットの数 >>'))
r = int(1/n*100)
print(f'ゴールできる確率は{r}%です')

# %%
#Exercise7
jp_price = 39980
print(f'このゲーム機は日本円で{jp_price}円です。\n米ドルでは${int(jp_price/108)}となります。')

# %%
#Exercise8
print('Five'*5)

# %%
#Exercise9
n = int(input('本数 >>'))
print(f'{int(n*1.5)}本です')

# %%
#Exercise10
radius = int(input('半径入力 >>'))
print('半径{}cmの円の面積は{}平方cmです。'.format(radius, radius**2*3.14))
print(f'半径{radius}cmの円の面積は{radius**2*3.14}平方cmです。')

# %%
#Exercise11
base = int(input('底辺 >>'))
height = int(input('高さ >>'))
print('底辺{}cmで高さ{}cmの三角形の面積は{}平方cmです。'.format(base, height, base*height/2))
print(f'底辺{base}cmで高さ{height}cmの三角形の面積は{base*height/2}平方cmです。')

# %%
#Exercise12
up = int(input('上底 >>'))
base = int(input('下底 >>'))
height = int(input('高さ >>'))
print('上底{}cmと下底{}cmで高さ{}cmの台形の面積は{}平方cmです。'.format(up, base, height, (up+base)*height/2))
print(f'上底{up}cmと下底{base}cmで高さ{height}cmの台形の面積は{(up+base)*height/2}平方cmです。')

# %%
#Exercise13
base = 35
height = 30
up = 20
trap = (up+base)*height/2
rect = base*height
tri = base*height/2
circle = (height/2)**2*3.14
print(f'総面積は{int(trap+rect+tri+circle)}平方cmです。')

# %%
#Exercise14
a = int(input('左辺入力 >>'))
b = int(input('右辺入力 >>'))
print(f'{a}割る{b}は、{a//b}余り{a%b}です')
#c,d = divmod(a, b)
#print(f'{a}割る{b}は、{c}余り{d}です')

# %%
#Exercise15
e = int(input('英語 >>'))
m = int(input('数学 >>'))
print(f'英語{e}点、数学{m}点の平均点は{(e+m)/2}点です')

# %%
#Exercise16
total = 1280
A = total//3+total%3
B = total//3
C = total//3
print(f'Aさんは{A}円、Bさんは{B}円、Cさんは{C}円支払いました')

# %%
#Exercise17
str1 = 'Which one would you like, Coffee or Tea?'
str2 = str1.replace('Coffee or Tea', 'Python or Java')
print(str1+'\n'+str2)

# %%
#Exercise18
w1 = 'This is a ballpen. This ballpen is comfortable to write on.'
print(w1)
print(w1.replace('ball', ''))

# %%
#Exercise19
s = input('入力 >>')
n = int(input('インデックス >>'))
print(s)
print(s[n:])

# %%
#Exercise20
words = 'しばらくすると信号機が赤に変わった'
index = words.find('赤')
print(words[:index]+'青'+words[index+1:])
#print(words[0:index]+'青'+words[index+1:len(words)])

# %%
#Exercise21
prefs = "兵庫県京都府大阪府奈良県和歌山県"
towns = "京都市和歌山市奈良市大阪市神戸市"
city = "西区北堀江"
print(f"{prefs[6:9]}{towns[10:13]}{city}")

# %%
#Exercise22
machines = 100
base = '(大阪店)'
base += 'ゲーム機の在庫：'
base += str(machines)
print(base)

# %%
#Exercise23
word = '   Hello World!   '
print(word.rstrip()+str(len(word.rstrip())))
print(word.lstrip()+str(len(word.lstrip())))
print(word.strip()+str(len(word.strip())))

# %%
#Exercise24
sweets = 'cake,ice cream,french toast,fruits,coffee'
items = sweets.split(',')
print(f'I like {items[2]} and {items[4]}')

# %%
#Exercise25
1var = 100
var2 = 'そのゲームは面白いので'+1var+'回はやりました。'
print(var2)

# %%
#Exercise26
zen = '''The Zen of Python, by Tim Peters
醜いより美しい方がいい
暗黙より明示の方がいい
複雑より単純の方がいい
極端な複雑よりただの複雑の方がいい
入れ子よりフラットの方がいい
蜜よりも疎の方がいい
読みやすさは大切だ'''
print('この文章は'+str(zen.count("\n")+1)+'行あります。')

# %%
#Exercise27
s = 113.04
n = s/4/3.14
print(f'表面積が113.04平方cmの球の半径は{n**0.5}cm')
print(f'表面積が113.04平方cmの球の半径は{pow(n, 0.5)}cm')

# %%
#Exercise28
turi = 1000 - 308
print(f'500円玉は{int(turi/500)}枚')
turi = turi % 500
print(f'100円玉は{int(turi/100)}枚')
turi = turi % 100
print(f'50円玉は{int(turi/50)}枚')
turi = turi % 50
print(f'10円玉は{int(turi/10)}枚')
turi = turi % 10
print(f'5円玉は{int(turi/5)}枚')
print(f'1円玉は{turi%5}枚')

# %%
#Exercise29
price = int(input('金額 >>'))
print(f'10000円札は{price//10000}枚')
price = price % 10000
print(f'5000円札は{price//5000}枚')
price = price % 5000
print(f'1000円札は{price//1000}枚')
price = price % 1000
print(f'500円玉は{price//500}枚')
price = price % 500
print(f'100円玉は{price//100}枚')
price = price % 100
print(f'50円玉は{price//50}枚')
price = price % 50
print(f'10円玉は{price//10}枚')
price = price % 10
print(f'5円玉は{price//5}枚')
print(f'1円玉は{price%5}枚')

# %%
#Exercise30
str1 = input('半角英字 >>')
print(str1.title())

# %%
#Exercise31
w1 = "abcd"
w2 = "wxyz"
new_w1 = w2[:2] + w1[2:]
new_w2 = w1[:2] + w2[2:]
print(new_w1 + ' ' + new_w2)

# %%
#Exercise32
word = input('入力 >>')
print(word[-2:] * 4)

# %%
#Exercise33
w1 = input('入力 >>')
w2 = input('数える文字列 >>')
num = w1.count(w2)
print(f'"{w1}"にある"{w2}"の数は、{num}個')

# %%
#Exercise34
kao = input('入力 >>')
print(kao)
print(f'左向きは{kao.count("(^^*)")}個、右向きは{kao.count("(*^^)")}個')

# %%
#Exercise35
kao = '(^^*)(^^*)(*^^)(^^*)(*^^)(*^^)(*^^)'
new_kao = kao[0:10]+kao[15:20]+kao[10:15]+kao[20:35]
print(new_kao)

# %%
#Exercise36
moto = '(^o^)/'
eye = input('目 >>')
mouth = input('口 >>')
print(f'({eye}{mouth}{eye})/')
print(f'{moto[0]}{eye}{mouth}{eye}{moto[-2:]}')

# %%
#Exercise37
w = input('入力 >>')
print(f'{w[:int(len(w)/2)]}')

# %%
#Exercise38
word = input('入力 >>')
num = int(input('文字数 >>'))
print(word[:num].upper() + word[num:])

# %%
#Exercise39
letters = 'abcdefghijklmnopqrstuvwxyz'
print(letters[-5:]) #最後の5文字
print(letters[10:-9]) #オフセット10から末尾より10文字まで
print(letters[::6]) #先頭から6文字ごと
print(letters[-7:-3]) #末尾の7文字手前から末尾の4文字手前まで
print(letters[::-1]) #逆順となる

# %%
#Exercise40
num = input('入力 >>')
n1 = int(num[:int(len(num)/2)]) *2
n2 = int(int(num[int(len(num)/2):]) / 2)
print(f'{str(n1)} {str(n2)}')

# %%
#Exercise41
N = int(input('入力1 >>'))
M = int(input('入力2 >>'))
print(f'{N}x{M}={N*M}の結果は{len(str(N*M))}桁')

# %%
#Exercise42
s1,s2 = input('入力 >>').split(',')
H = int(s1)
M = int(s2)
M += 5
H += M // 60
print(f'{H%24}時{M%60}分')
#print(f'{H%24:02d}時{M%60:02d}分')

# %%
#Exercise43
a = 36.24
b = 36.354
print('体温は{:.1f}です。'.format(a))
print(f'体温は{a:.1f}です。')
print('体温は{:.2f}です。'.format(b))
print(f'体温は{b:.2f}です。')
print('体温は{:.0f}です。'.format(a))
print(f'体温は{a:.0f}です。')
H, M, S = 3, 5, 15
print('{:02}:{:02}:{:02}の計測です。'.format(H,M,S))
print(f'{H:02}:{M:02}:{S:02}の計測です。')

# %%
#Exercise44
print(0b1000 + 0b0111)
print(0b1001 + 0b0110)
print(0b1010 + 0b0101)
print(0b1011 + 0b0100)
print(0b1100 + 0b0011)
print(0b1101 + 0b0010)
print(0b1110 + 0b0001)
print(0b1111 + 0b0000)
print(0x80 * 2)

# %%
#Exercise45
dist = int(input('距離 >>'))
speed = int(input('時速 >>'))
print(f'AからBへは{dist//speed}時間{int((dist%speed)/speed*60)}分必要です')

# %%
#Exercise46
pen = 350
note = 1250
postit = 430
print(f'合計は20%割引で{int((pen+note+postit)*0.8)}円となります')

# %%
#Exercise47
num = input('入力 >>')
n1 = int(num)
n2 = int(num*2)
n3 = int(num*3)
print(n1,n2,n3)
print(n1+n2+n3)

# %%
#Exercise48
weight = int(input('体重 >>'))
tall = int(input('身長 >>'))
bmi = weight/((tall/100)**2)
jst = ((tall/100)**2)*22
print(f'体重は{weight}kgで身長が{tall}cmのBMIは{bmi}です。')
print(f'身長が{tall}cmの適正体重は{jst}kgです。')

# %%
#Exercise49
N = int(input('予算 >>'))
M = int(input('人数 >>'))
print(f'お年玉は{(N // (M*1000)) * 1000}円')

# %%
#Exercise50
num = int(input('入力 >>'))
H = num//3600
M = num%3600//60
S = num%60
print(f'{H}時間{M}分{S}秒')

# %%
#Exercise51
w1,w2 = input('入力 >>').split(',')
middle = int(len(w1)/2)
w3 = w1[:middle:]+w2+w1[middle:]
print(w3)

# %%
#Exercise52
n = int(input('入力 >>'))
print(f'{n}番目の偶数は{n*2-2}')

# %%
#Exercise53
string = input('入力 >>')
print(string[:3]*3)

# %%
#Exercise54
string = input('入力 >>')
length = len(string)
pos = length//3
print(f'{string[pos:pos*2]}')

# %%
#Exercise55
string,num = input('入力 >>').split(',')
num = int(num)
print(string[::num])

# %%
#Exercise56
n1 = int(input('入力 >>'))
n2 = int(str(n1)[::-1])
print(f'{n1}+{n2}={n1+n2}')

# %%
#Exercise57
n1 = int(input('入力 >>'))
n2 = n1//3
n3 = ((n1%3)//2)+n2
n4 = ((n1%3)//2)+((n1%3)%2)+n2
print(f'{n2}+{n3}+{n4}={n1}')

# %%
#Exercise58
frame = int(input('時間(分) >>'))
print(f'総フレーム数：{frame*60*60}')

# %%
#Exercise59
n1 = (0.45+1.8)/0.3
n2 = (0.45+1.8)/(0.3+0.035)
print(f'計算上は{int(n1)}人、実際には{int(n2)}人')

# %%
#Exercise60
D = int(input('巣穴の距離 >>'))
L = int(input('大ジャンプの距離 >>'))
print(f'必要回数：{D // L + D % L}')
